# %%
from IPython.display import YouTubeVideo
YouTubeVideo('rmuRoAf9-bo', width=800, height=500)

# %%
import pandas as pd
pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/var_names.csv")
pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv")
# Out:
# /tmp/ipykernel_51/1536837149.py:3: DtypeWarning: Columns (408,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1463,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv")
#         UNIQUE_id  UNIQUE_num_records ELIGIBLE_consent GEO_residence_canada  \
# 0      cscs_00001                   1              Yes                  Yes
# 1      cscs_00002                   1              Yes                  Yes
# 2      cscs_00003                   1              Yes                  Yes
# 3      cscs_00005                   1              Yes                  Yes
# 4      cscs_00006                   1              Yes                  Yes
# ...

# %% [markdown]
# 1. Describe (a) the variables you plan to explore, and (b) the analysis you plan to perform
# 2. Describe (a) the possible results your analysis may produce, and (b) how this could be relevant for the objectives of the course project
# 3. Include your results if you have already completed an analysis

# %% [markdown]
# These are the analysis I proposed based which on how me and my teammates plan to perform and to investigate. I would alter some proposal as I came into conclusion with my teammate for future adjustments.
#
# (a)
#
# Analysis 1: Social Support Sources
#
# -Interactions with Family, Friends, Coworkers, Neighbors Q117-
#
# Analysis 2: Mental Health and Social Support
#
# -Self-reported WELLNESS/Mental health score Q50-61
#
# Analysis 3: Community Engagement and Life Satisfaction
#
# -Community Interactions Q171
#
# (b)
#
# # 1.Social Support Sources
#
# -The focus varibales here on Data Summarization and Visualization would be Sources of social support for instance family, friends, coworkers, neighbors and how frequenily do these support interacts. This analysis aims to examine different sources of social support available to individuals, such as family, friends, coworkers, and neighbors. Each source represents a distinct way that individuals connect with and receive support from their social networks, which may vary greatly depending on life circumstances.
#
# -The first step here would be involving summarizing the data to understand the distribution of each social support source—that is, how many people identify each group as a primary source of support. We will further break down this data by different demographic variables, such as age, gender, and socioeconomic status, to reveal patterns or disparities in where people turn for support. Following that, we would summarize and visualize the data to show the distribution and frequency of social support sources across different demographic groups. Bar charts, histograms, and pie charts could effectively convey this data.
#
# -The Expected Results here I could think of would be the visualizations might show which sources of social support are most prevalent in different age or socioeconomic groups. For example, younger individuals primarily receive support from friends, while older individuals rely more on family or neighbors. We might also see that people in different income groups vary in their sources of support, with some relying more on coworkers or community-based connections. Clear, visual summaries of social support could reflect how groups like ages are most or least connected, providing insights for targeted interventions to enhance social support networks.
#
# # 2.Mental Health and Social Support
#
# -For this scenario I would be using confidence Intervals and Hypothesis Testing to investigate how the Levels of social support and self-reported mental health scores change based on constructing a confidence intervals for average mental health scores for groups with high and low social support. Then, probably we will conduct a hypothesis test, mostly a t-test to evaluate if there is a significant difference in mental health scores between individuals with high versus low social support.
#
# -As I said, the analysis involves in constructing confidence intervals for the average mental health scores within two distinct groups: individuals with high levels of social support and those with low levels. These groups can be defined based on survey responses or social support scores, with thresholds distinguishing "high" and "low" support categories. Calculating confidence intervals for each group will allow us to estimate the range within which the true mean mental health score lies for each group, giving us insight into whether mental health outcomes differ meaningfully between these two support levels.
#
# -As for the results, which I asked my friends, which that the confidence intervals will differ significantly between groups, and a hypothesis test could reveal whether the mental health benefits of social support are statistically significant. This approach provides a quantitative assessment of social support’s impact on mental health, aligning with the course’s objective to scientifically highlight social connection benefits. However, if the confidence intervals overlap significantly or the t-test does not produce a significant result, it may suggest that social support levels do not have a strong direct impact on mental health in this dataset.
#
# # 3.Community Engagement and Life Satisfaction
#
# -I would use the Simple Linear Regression for community engagement activities and overall life satisfaction scores.
# This could examine whether increased community engagement predicts higher life satisfaction. Community engagement can encompass various forms of social participation, such as volunteering, attending local events, participating in group activities, or contributing to community organizations. These activities foster a sense of belonging, increase interaction with others, and potentially build a support network. On the other hand, life satisfaction is a broad measure of an individual’s overall contentment with life, encompassing both emotional and practical aspects of well-being.There's a high chance that a positive regression coefficient occurs which might indicate that higher engagement levels are associated with higher life satisfaction.
#
# -In this model, community engagement serves as the predictor variable, while life satisfaction is the outcome we’re trying to predict. The simple linear regression will calculate a regression line based on the data, allowing us to see whether there is a positive or negative trend between the two variables. The slope of this line, represented by the regression coefficient, will show the strength and direction of the association. If the coefficient is positive, it suggests that as community engagement increases, life satisfaction also tends to increase.
#
# -I believed that the relevance to objectives for this would be showing a predictive relationship between community engagement and life satisfaction reinforces the importance of social connection for well-being. A significant result would indicate that the positive relationship between community engagement and life satisfaction is unlikely to be due to random chance. Moreover, we may also look at the Chi-squared value, which measures how much of the variation in life satisfaction can be explained by community engagement alone.
